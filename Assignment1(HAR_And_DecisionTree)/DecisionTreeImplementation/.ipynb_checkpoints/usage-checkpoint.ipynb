# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tree.base import DecisionTree
from metrics import *
from tree.utils import preprocessing
# Out:
# D:\ruddhi\iitgn-study\ML\Regressors\MachineLearning_Regressors\Assignment1(HAR_And_DecisionTree)\DecisionTreeImplementation
# D:\ruddhi\iitgn-study\ML\Regressors\MachineLearning_Regressors\Assignment1(HAR_And_DecisionTree)\DecisionTreeImplementation

# %%
np.random.seed(42)

# %%
N = 30
P = 5
X = pd.DataFrame(np.random.randn(N, P))
y = pd.Series(np.random.randn(N))
X,y=preprocessing(X,y)
# Out:
# Real output

# %%
X
# Out:
#            0         1         2         3         4
# 0   0.496714 -0.138264  0.647689  1.523030 -0.234153
# 1  -0.234137  1.579213  0.767435 -0.469474  0.542560
# 2  -0.463418 -0.465730  0.241962 -1.913280 -1.724918
# 3  -0.562288 -1.012831  0.314247 -0.908024 -1.412304
# 4   1.465649 -0.225776  0.067528 -1.424748 -0.544383
# 5   0.110923 -1.150994  0.375698 -0.600639 -0.291694
# 6  -0.601707  1.852278 -0.013497 -1.057711  0.822545
# 7  -1.220844  0.208864 -1.959670 -1.328186  0.196861
# 8   0.738467  0.171368 -0.115648 -0.301104 -1.478522
# 9  -0.719844 -0.460639  1.057122  0.343618 -1.763040
# 10  0.324084 -0.385082 -0.676922  0.611676  1.031000
# 11  0.931280 -0.839218 -0.309212  0.331263  0.975545
# 12 -0.479174 -0.185659 -1.106335 -1.196207  0.812526
# 13  1.356240 -0.072010  1.003533  0.361636 -0.645120
# 14  0.361396  1.538037 -0.035826  1.564644 -2.619745
# 15  0.821903  0.087047 -0.299007  0.091761 -1.987569
# 16 -0.219672  0.357113  1.477894 -0.518270 -0.808494
# 17 -0.501757  0.915402  0.328751 -0.529760  0.513267
# 18  0.097078  0.968645 -0.702053 -0.327662 -0.392108
# 19 -1.463515  0.296120  0.261055  0.005113 -0.234587
# 20 -1.415371 -0.420645 -0.342715 -0.802277 -0.161286
# 21  0.404051  1.886186  0.174578  0.257550 -0.074446
# 22 -1.918771 -0.026514  0.060230  2.463242 -0.192361
# 23  0.301547 -0.034712 -1.168678  1.142823  0.751933
# 24  0.791032 -0.909387  1.402794 -1.401851  0.586857
# 25  2.190456 -0.990536 -0.566298  0.099651 -0.503476
# 26 -1.550663  0.068563 -1.062304  0.473592 -0.919424
# 27  1.549934 -0.783253 -0.322062  0.813517 -1.230864
# 28  0.227460  1.307143 -1.607483  0.184634  0.259883
# 29  0.781823 -1.236951 -1.320457  0.521942  0.296985

# %%
y
# Out:
# 0     0.250493
# 1     0.346448
# 2    -0.680025
# 3     0.232254
# 4     0.293072
# 5    -0.714351
# 6     1.865775
# 7     0.473833
# 8    -1.191303
# 9     0.656554
# 10   -0.974682
# 11    0.787085
# 12    1.158596
# 13   -0.820682
# 14    0.963376
# 15    0.412781
# 16    0.822060
# 17    1.896793
# 18   -0.245388
# 19   -0.753736
# 20   -0.889514
# 21   -0.815810
# 22   -0.077102
# 23    0.341152
# 24    0.276691
# 25    0.827183
# 26    0.013002
# 27    1.453534
# 28   -0.264657
# 29    2.720169
# dtype: float64

# %%
for criteria in ["mse"]:
    tree = DecisionTree(criterion=criteria) 
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print("Criteria :", criteria)
    print("RMSE: ", rmse(y_hat, y))
    print("MAE: ", mae(y_hat, y))
# Out:
# If 1 <= -1.1939721441501923 ?
#     Value : 2.720169166589619
# Else :
#
#     If 4 <= 0.3865751136808898 ?
#         If 0 <= 1.5077915869695468 ?
#             If 4 <= -1.7439789939378834 ?
#                 If 1 <= 0.8125418173520702 ?
#                     Value : 0.4127809269364983
#                 Else :
#
#                     Value : 0.9633761292443218
#             Else :
#
#                 If 2 <= 1.24071347131677 ?
#                     Value : -1.1913034972026486
#                 Else :
#
#                     Value : 0.82206015999449
#         Else :
#
#             If 0 <= 1.870195015413759 ?
#                 Value : 1.4535340771573169
#             Else :
#
#                 Value : 0.8271832490360238
#     Else :
#
#         If 0 <= -0.35665559739723524 ?
#             If 0 <= -0.4904656407149133 ?
#                 If 0 <= -0.5517318279069667 ?
#                     Value : 1.8657745111447566
#                 Else :
#
#                     Value : 1.8967929826539474
#             Else :
#
#                 Value : 1.158595579007404
#         Else :
#
#             If 4 <= 1.003272324809155 ?
#                 If 0 <= 0.8611560330796227 ?
#                     Value : 0.27669079933001905
#                 Else :
#
#                     Value : 0.787084603742452
#             Else :
#
#                 Value : -0.9746816702273214
# Criteria : mse
# RMSE:  0.698684547398283
# MAE:  0.43525426887411

# %%
# Test case 2
# Real Input and Discrete Output

N = 30
P = 5
X = pd.DataFrame(np.random.randn(N, P))
y = pd.Series(np.random.randint(P, size=N), dtype="category")
X,y=preprocessing(X,y)
# Out:
# Discrete output

# %%
y
# Out:
# 0     4
# 1     4
# 2     1
# 3     1
# 4     1
# 5     4
# 6     2
# 7     4
# 8     2
# 9     2
# 10    1
# 11    3
# 12    0
# 13    1
# 14    1
# 15    3
# 16    0
# 17    4
# 18    4
# 19    1
# 20    0
# 21    1
# 22    2
# 23    1
# 24    1
# 25    4
# 26    4
# 27    4
# 28    2
# 29    4
# dtype: category
# Categories (5, int32): [0, 1, 2, 3, 4]

# %%
for criteria in ["entropy", "gini_index"]:
    tree = DecisionTree(criterion=criteria) 
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print("Criteria :", criteria)
    print("Accuracy: ", accuracy(y_hat, y))
    for cls in y.unique():
        print(f"Precision for Class-{cls}: ", precision(y_hat, y, cls))
        print(f"Recall for Class-{cls}: ", recall(y_hat, y, cls))
# Out:
# If 0 <= 0.5164969924782189 ?
#     If 1 <= 1.0083193995209832 ?
#         If 2 <= -0.4498157567688338 ?
#             If 0 <= -0.6307158537095157 ?
#                 Value : 0
#             Else :
#
#                 If 0 <= -0.27131174309911177 ?
#                     Value : 1
#                 Else :
#
#                     Value : 2
#         Else :
#
#             If 2 <= -0.13234745834482112 ?
#                 Value : 4
#             Else :
#
#                 If 4 <= 2.9983377899900234 ?
#                     Value : 1
#                 Else :
#
#                     Value : 4
#     Else :
#
#         If 2 <= -0.6496204272273054 ?
#             If 0 <= -0.8660086274155504 ?
#                 Value : 4
#             Else :
#
#                 Value : 3
#         Else :
#
#             Value : 4
# Else :
#
#     If 1 <= -1.9462038896246776 ?
#         Value : 3
#     Else :
#
#         If 4 <= -0.7267202584186923 ?
#             Value : 4
#         Else :
#
#             If 0 <= 0.9239599087303167 ?
#                 If 0 <= 0.5982789292290867 ?
#                     Value : 2
#                 Else :
#
#                     Value : 4
#             Else :
#
#                 Value : 2
# Criteria : entropy
# Accuracy:  0.9
# Precision for Class-4:  1.0
# Recall for Class-4:  1.0
# Precision for Class-1:  0.8181818181818182
# Recall for Class-1:  0.9
# Precision for Class-2:  0.8333333333333334
# Recall for Class-2:  1.0
# Precision for Class-3:  1.0
# Recall for Class-3:  1.0
# Precision for Class-0:  1.0
# Recall for Class-0:  0.3333333333333333
# If 0 <= 0.5164969924782189 ?
#     If 1 <= 1.0083193995209832 ?
#         If 2 <= -0.7357749579035922 ?
#             If 0 <= -0.41496725329268236 ?
#                 Value : 0
#             Else :
#
#                 Value : 2
#         Else :
#
#             If 4 <= 2.9983377899900234 ?
#                 If 2 <= -0.13234745834482112 ?
#                     Value : 1
#                 Else :
#
#                     Value : 1
#             Else :
#
#                 Value : 4
#     Else :
#
#         If 2 <= -0.6496204272273054 ?
#             If 0 <= -0.8660086274155504 ?
#                 Value : 4
#             Else :
#
#                 Value : 3
#         Else :
#
#             Value : 4
# Else :
#
#     If 1 <= -1.9462038896246776 ?
#         Value : 3
#     Else :
#
#         If 4 <= -0.7267202584186923 ?
#             Value : 4
#         Else :
#
#             If 0 <= 0.9239599087303167 ?
#                 If 0 <= 0.5982789292290867 ?
#                     Value : 2
#                 Else :
#
#                     Value : 4
#             Else :
#
#                 Value : 2
# Criteria : gini_index
# Accuracy:  0.8666666666666667
# Precision for Class-4:  1.0
# Recall for Class-4:  0.9
# Precision for Class-1:  0.7142857142857143
# Recall for Class-1:  1.0
# Precision for Class-2:  1.0
# Recall for Class-2:  0.8
# Precision for Class-3:  1.0
# Recall for Class-3:  1.0
# Precision for Class-0:  1.0
# Recall for Class-0:  0.3333333333333333

# %%
# Test case 3
# Discrete Input and Discrete Output

N = 30
P = 5
X = pd.DataFrame({i: pd.Series(np.random.randint(P, size=N), dtype="category") for i in range(5)})
y = pd.Series(np.random.randint(P, size=N), dtype="category")
X,y=preprocessing(X,y)
# Out:
# Discrete output

# %%
for criteria in ["entropy", "gini_index"]:
    tree = DecisionTree(criterion=criteria) 
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print("Criteria :", criteria)
    print("Accuracy: ", accuracy(y_hat, y))
    for cls in y.unique():
        print(f"Precision for Class-{cls}: ", precision(y_hat, y, cls))
        print(f"Recall for Class-{cls}: ", recall(y_hat, y, cls))
# Out:
# If 1_0 <= 0.0 ?
#     If 1_4 <= 0.0 ?
#         If 4_3 <= 0.0 ?
#             If 3_2 <= 0.0 ?
#                 If 3_0 <= 0.0 ?
#                     Value : 2
#                 Else :
#
#                     Value : 0
#             Else :
#
#                 If 0_4 <= 0.0 ?
#                     Value : 3
#                 Else :
#
#                     Value : 0
#         Else :
#
#             If 0_1 <= 0.0 ?
#                 Value : 1
#             Else :
#
#                 Value : 3
#     Else :
#
#         If 2_3 <= 0.0 ?
#             If 0_4 <= 0.0 ?
#                 Value : 3
#             Else :
#
#                 Value : 1
#         Else :
#
#             Value : 1
# Else :
#
#     If 4_1 <= 0.0 ?
#         If 0_2 <= 0.0 ?
#             If 0_3 <= 0.0 ?
#                 Value : 4
#             Else :
#
#                 If 3_1 <= 0.5 ?
#                     Value : 4
#                 Else :
#
#                     Value : 0
#         Else :
#
#             Value : 0
#     Else :
#
#         Value : 0
# Criteria : entropy
# Accuracy:  0.9333333333333333
# Precision for Class-0:  0.8571428571428571
# Recall for Class-0:  0.8571428571428571
# Precision for Class-4:  1.0
# Recall for Class-4:  1.0
# Precision for Class-1:  1.0
# Recall for Class-1:  0.8888888888888888
# Precision for Class-2:  0.8333333333333334
# Recall for Class-2:  1.0
# Precision for Class-3:  1.0
# Recall for Class-3:  1.0
# If 1_4 <= 0.0 ?
#     If 1_0 <= 0.0 ?
#         If 4_3 <= 0.0 ?
#             If 0_1 <= 0.0 ?
#                 If 0_3 <= 0.0 ?
#                     Value : 0
#                 Else :
#
#                     Value : 2
#             Else :
#
#                 Value : 2
#         Else :
#
#             If 0_1 <= 0.0 ?
#                 Value : 1
#             Else :
#
#                 Value : 3
#     Else :
#
#         If 4_1 <= 0.0 ?
#             If 0_2 <= 0.0 ?
#                 If 0_3 <= 0.0 ?
#                     Value : 4
#                 Else :
#
#                     Value : 0
#             Else :
#
#                 Value : 0
#         Else :
#
#             Value : 0
# Else :
#
#     If 2_3 <= 0.0 ?
#         If 0_4 <= 0.0 ?
#             Value : 3
#         Else :
#
#             Value : 1
#     Else :
#
#         Value : 1
# Criteria : gini_index
# Accuracy:  0.8333333333333334
# Precision for Class-0:  0.6
# Recall for Class-0:  0.8571428571428571
# Precision for Class-4:  1.0
# Recall for Class-4:  0.75
# Precision for Class-1:  1.0
# Recall for Class-1:  0.8888888888888888
# Precision for Class-2:  0.8333333333333334
# Recall for Class-2:  1.0
# Precision for Class-3:  1.0
# Recall for Class-3:  0.6

# %%
# Test case 4
# Discrete Input and Real Output

N = 30
P = 5
X = pd.DataFrame({i: pd.Series(np.random.randint(P, size=N), dtype="category") for i in range(5)})
y = pd.Series(np.random.randn(N))
X,y=preprocessing(X,y)
# Out:
# Real output

# %%
for criteria in ["mse"]:
    tree = DecisionTree(criterion=criteria) 
    tree.fit(X, y)
    y_hat = tree.predict(X)
    tree.plot()
    print("Criteria :", criteria)
    print("RMSE: ", rmse(y_hat, y))
    print("MAE: ", mae(y_hat, y))
# Out:
# If 2_1 <= 0.0 ?
#     If 1_4 <= 0.0 ?
#         If 3_0 <= 0.0 ?
#             If 0_4 <= 0.0 ?
#                 If 4_0 <= 0.0 ?
#                     Value : -0.6039851867158206
#                 Else :
#
#                     Value : 1.2012139221639448
#             Else :
#
#                 If 3_1 <= 0.0 ?
#                     Value : -1.129706854657618
#                 Else :
#
#                     Value : -0.32602353216784113
#         Else :
#
#             If 2_2 <= 0.0 ?
#                 If 1_1 <= 0.0 ?
#                     Value : 0.2544208433012131
#                 Else :
#
#                     Value : 1.4415686206579004
#             Else :
#
#                 Value : -0.5768918695231487
#     Else :
#
#         If 2_2 <= 0.5 ?
#             Value : 2.075400798645439
#         Else :
#
#             If 0_2 <= 0.0 ?
#                 If 0_1 <= 0.5 ?
#                     Value : 1.0062928092144405
#                 Else :
#
#                     Value : 0.8356921120651418
#             Else :
#
#                 Value : -0.2030453860429927
# Else :
#
#     If 1_1 <= 0.0 ?
#         If 0_1 <= 0.0 ?
#             If 1_0 <= 0.0 ?
#                 If 0_2 <= 0.5 ?
#                     Value : 0.8711247034316923
#                 Else :
#
#                     Value : 0.3376026620752022
#             Else :
#
#                 If 0_2 <= 0.5 ?
#                     Value : -0.15567723539207948
#                 Else :
#
#                     Value : -0.7968952554704768
#         Else :
#
#             Value : -2.038124535177854
#     Else :
#
#         Value : -2.4716445001272893
# Criteria : mse
# RMSE:  0.4592036966731692
# MAE:  0.2477957395751981
